# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikpaii/workshop-MITE/blob/main/workshop2aftnoon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 36.0 MB/s eta 0:00:00
# ...

# %%
import psycopg2
from google.colab import userdata

DATABASE_URL='postgresql://neondb_owner:npg_NkBnMtb5du8W@ep-silent-frog-aib74m4t-pooler.c-4.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require'

# %%
try:
  conn=psycopg2.connect(DATABASE_URL)
  cursor=conn.cursor()
  print("Connected to Database")
  cursor.execute("SELECT version()")
  print(cursor.fetchone())
  cursor.execute("SELECT current_database() ")
  print(cursor.fetchone())
except Exception as e:
  print("Error:",e)
# Out:
# Connected to Database
# ('PostgreSQL 17.7 (bdd1736) on aarch64-unknown-linux-gnu, compiled by gcc (Debian 12.2.0-14+deb12u1) 12.2.0, 64-bit',)
# ('neondb',)

# %%
cursor.execute(
    """
    CREATE TABLE IF NOT EXISTS student
    (student_id SERIAL  PRIMARY KEY,
    roll_no VARCHAR(20) UNIQUE NOT NULL,
    name VARCHAR(20) NOT NULL
    )"""
)

conn.commit()
print("Student Table Created Successfully")
cursor.execute("SELECT * FROM student")
print(cursor.fetchall())
# Out:
# Student Table Created Successfully
# []

# %%
cursor.execute(
    """
    CREATE TABLE IF NOT EXISTS subject
    (subject_id SERIAL  PRIMARY KEY,
    subject_code VARCHAR(20) UNIQUE NOT NULL,
    subject_name VARCHAR(100) NOT NULL
    )"""
)

conn.commit()
print("Subject Table Created Successfully")
cursor.execute("SELECT * FROM subject")
print(cursor.fetchall())
# Out:
# Subject Table Created Successfully
# []

# %%
cursor.execute(
    """ CREATE TABLE IF NOT EXISTS marks
    ( marks_id SERIAL PRIMARY KEY,
    student_id INT NOT NULL,
    subject_id INT NOT NULL,
    marks INT NOT NULL CHECK (marks>=0 AND marks<=100),

    CONSTRAINT fk_student
    FOREIGN KEY(student_id)
    REFERENCES student(student_id)
    ON DELETE CASCADE,

    CONSTRAINT fk_subject
    FOREIGN KEY(subject_id)
    REFERENCES subject(subject_id)
    ON DELETE CASCADE,

    CONSTRAINT unique_student_subject
    UNIQUE(student_id,subject_id)

    )"""
)

conn.commit()
print("Marks Table Created Successfully")
cursor.execute("SELECT * FROM marks")
print(cursor.fetchall())
# Out:
# Marks Table Created Successfully
# []

# %%
cursor.execute("INSERT INTO student(roll_no,name) VALUES (%s,%s)",("R003","Rai"))

cursor.execute("INSERT INTO student(roll_no,name) VALUES (%s,%s)",("R004","Kai"))



conn.commit()
